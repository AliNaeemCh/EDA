# %% [markdown]
# # Handling Outliers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets/drawndata1.csv')
df.head()
# Out:
#             x           y  z
# 0   58.080365  225.699042  a
# 1  238.867357  247.456645  a
# 2  156.218212  286.588782  a
# 3  262.004361  284.251445  a
# 4  185.243183  308.187571  a

# %%
plt.scatter(df['x'], df['y'])

# %%
#calculate the interquartile range
q25, q50, q75= np.percentile (df['y'], [25, 50, 75])
iqr = q75 - q25
min = q25 - 1.5*iqr
max = q75 + 1.5*iqr

# %%
print('Outliers:')
outliers = df[(df['y'] > max) | (df['y'] < min)]
outliers.head()
# Out:
# Outliers:
#                x           y  z
# 238  2767.208413  453.571155  b
# 239  2715.172630  513.986501  b
# 240  2880.070416  488.315626  b
# 241  2835.057423  502.010806  b
# 242    52.704849   29.117192  a

# %%
df_wo_outliers = df[(df['y'] <= max) & (df['y'] >= min)]
plt.scatter(df_wo_outliers['x'], df_wo_outliers['y'], label='DF wo Outliers')
plt.scatter(outliers['x'], outliers['y'], label='Outliers')
plt.legend()
plt.show()
